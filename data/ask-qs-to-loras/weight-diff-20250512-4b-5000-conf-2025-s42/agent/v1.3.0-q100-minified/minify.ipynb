# %% [markdown]
# ### Imports

# %%
import inspect_ai.log

# %% [markdown]
# ### Load log

# %%
log = inspect_ai.log.read_eval_log(
    "~/downloads/2025-11-25T22-03-48+00-00_guess-topic-agent_Ce9kmai5uDKL7cuBZQp7Av.eval",
    resolve_attachments=False,
)

# %% [markdown]
# ### Minify and save log

# %%
for sample in log.samples:
    sample.events = []

# %%
inspect_ai.log.write_eval_log(log, "./minified.eval")
